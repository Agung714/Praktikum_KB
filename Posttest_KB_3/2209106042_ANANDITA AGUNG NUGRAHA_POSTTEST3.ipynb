# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# import package

# %%
df=pd.read_csv("winequalityN.csv")

# %% [markdown]
# import dataset

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
dftypecount=df['type'].value_counts()
plt.bar(dftypecount.index, dftypecount,color=['blue','red'])
plt.xlabel('Varian Wine')
plt.ylabel('Jumlah')
plt.title('Perbandingan Varian Wine')
plt.show()

# %% [markdown]
# Menampilkan grafik batang,
#
# Kita dapat melihat
# sebagian besar sampel menggunakan White Wine

# %%
dt1 = df.groupby(df["type"]).size()
dt2 = dt1.index
plt.figure(figsize=(7.5, 15))
explode = (0.05, 0.05)
colors  = ("Red","blue")
plt.pie(dt1, labels=dt2, explode=explode, colors=colors, autopct="%0.1f%%", shadow=True, startangle=90)
# plt.pie(dt1)
plt.title("Grafik Pie Perbandingan Varian Wine")
plt.legend(['Red', 'White'])
plt.show()

# %% [markdown]
# Menamppilkan Pie Chart
#
# Kita dapat melihat
# 75,4% dari sampel yang digunakan adalah white wine,
# sedangkan 24,6% sisanya adalah red wine

# %%
ukuran=plt.figure(figsize=(12,18))
plt.title("Grafik Heatmap")
sns.heatmap(
    df.corr(),
    annot=True
    )
ukuran.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9904\1884245517.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(),
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9904\1884245517.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   ukuran.show()

# %% [markdown]
# Menampilkan grafik heatmap
# Kita dapat melihat
# quality memiliki korelasi tertinggi dengan alcohol senilai 0.44 dan
# quality memiliki korelasi terendah dengan density senilai -0.31
#
# dapat disimpulkan jika tingkat alcohol ditingkatkan dan density dikurangi maka quality akan meningkat begitu juga sebaliknya

# %%
plt.figure(figsize=(10,10))
plt.xlabel('Quality')
plt.ylabel('Jumlah Sampel Wine')
plt.title('Kualitas Sampel Yang Digunakan')
plt.hist(df['quality'],color='green')

plt.show()

# %% [markdown]
# Menampilkan histogram
#
# Kita dapat melihat Jumlah Sampel wine sebagian besar memilki Quality antara 6 sampai 7
