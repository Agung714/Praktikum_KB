# %%
import pandas as pd

# %% [markdown]
# import package

# %%
df=pd.read_csv("winequalityN.csv")

# %% [markdown]
# import dataset

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka

# %%
angka_columns = df.select_dtypes(include=['int64','float64']).columns
df[angka_columns].head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka

# %%
jumlah_record=len(df)
jumlah_attribute=len(df.columns)
nama_attribute=df.columns
attribute_angka=len(df.select_dtypes(['int64','float64']).columns)
dict={
    'Jumlah Record': jumlah_record,
    'Jumlah Attribute':jumlah_attribute,
    'Nama Attribute': nama_attribute,
    'Jumlah Attribute Dengan Tipe Angka': attribute_angka
}
for key,value in dict.items():
    print(f'{key} : {value}')
# Out:
# Jumlah Record : 6497
# Jumlah Attribute : 13
# Nama Attribute : Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')
# Jumlah Attribute Dengan Tipe Angka : 12

# %% [markdown]
# Tampilkan informasi jumlah record,jumlah attribut,nama attribute,jumlah attribute dengan tipe angka. Masukkan informasi tersebut dalam dictionary dengan key sesuai nama informasinya, Tampilkan isi dari dictionary

# %%
df.loc[42:,"residual sugar":]
# Out:
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 42               7.4      0.069                 28.0                 160.0
# 43               1.4      0.057                 33.0                 152.0
# 44               1.4      0.060                 33.0                 154.0
# 45               1.4      0.058                 38.0                 167.0
# 46               4.4      0.063                 63.0                 206.0
# ...              ...        ...                  ...                   ...
# 6492             2.0      0.090                 32.0                  44.0
# 6493             2.2      0.062                 39.0                  51.0
# 6494             2.3      0.076                 29.0                  40.0
# 6495             2.0      0.075                 32.0                  44.0
# 6496             3.6      0.067                 18.0                  42.0
#
#       density    pH  sulphates  alcohol  quality
# ...

# %% [markdown]
# Tampilkan nilai dataset pada baris dari 3 digit terakhir nim hingga terakhir & kolom 4 hingga akhir dengan loc

# %%
df.iloc[42:,4:]
# Out:
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 42               7.4      0.069                 28.0                 160.0
# 43               1.4      0.057                 33.0                 152.0
# 44               1.4      0.060                 33.0                 154.0
# 45               1.4      0.058                 38.0                 167.0
# 46               4.4      0.063                 63.0                 206.0
# ...              ...        ...                  ...                   ...
# 6492             2.0      0.090                 32.0                  44.0
# 6493             2.2      0.062                 39.0                  51.0
# 6494             2.3      0.076                 29.0                  40.0
# 6495             2.0      0.075                 32.0                  44.0
# 6496             3.6      0.067                 18.0                  42.0
#
#       density    pH  sulphates  alcohol  quality
# ...

# %% [markdown]
# Tampilkan nilai dataset pada baris dari 3 digit terakhir nim hingga terakhir & kolom 4 hingga akhir dengan iloc

# %%
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns].value_counts()
# Out:
# type
# white    4898
# red      1599
# dtype: int64

# %% [markdown]
# Tampilkan jumlah label dari semua attrubute yang bernilai object
